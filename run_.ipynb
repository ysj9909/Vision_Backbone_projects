# %%
from Factory import Factory

f=Factory('Plan-2012.12.24.csv')
f.run()
# Out:
# No : 1 , SerialNum :  P11M8738 ,Model: R180LC-9S
# No : 2 , SerialNum :  P11N0001 ,Model: R220LC-9S
# No : 3 , SerialNum :  P11N0002 ,Model: R160LC-9S
# No : 4 , SerialNum :  P11N0006 ,Model: R220LC-9S
# No : 5 , SerialNum :  P11N0007 ,Model: R160LC-9S
# No : 6 , SerialNum :  P11N0008 ,Model: R220LC-9S
# No : 7 , SerialNum :  P11N0009 ,Model: R220LC-9S
# No : 8 , SerialNum :  P11N0011 ,Model: R160LC-9S
# No : 9 , SerialNum :  P11N0027 ,Model: R220LC-9S
# No : 10 , SerialNum :  P11N0028 ,Model: R220LC-9S(L/R)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-795ef7573861> in <module>
#       2
#       3 f=Factory('Plan-2012.12.24.csv')
# ----> 4 f.run()
#
# ~\Desktop\3학년\데이터_구조_및_분석_문인철교수님\Provided_Code_week4\Factory.py in run(self)
#      42                         if product != 'none':
# ...
